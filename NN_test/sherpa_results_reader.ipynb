# %%
import numpy as np
import pathlib
from pprint import pprint
from get_best_sherpa_result import get_best_sherpa_result, show_sherpa_results
path = pathlib.Path.cwd()

run_types = ["LL", "HL"]
rinvs = ["0p3"]
for run_type in run_types:
    for rinv in rinvs: 
        try:
            result = get_best_sherpa_result(run_type, rinv)
            print(run_type, rinv)
            pprint(result)
            print(show_sherpa_results(run_type, rinv))
        except:
            pass
# Out:
# LL 0p3
# {'Iteration': 14,
#  'Objective': 0.8186426758766174,
#  'Status': 'COMPLETED',
#  'accuracy': 0.7393466830253601,
#  'auc': 0.8186426758766174,
#  'batch_size': 32.0,
#  'conv_blocks': 2.0,
#  'dense_layers': 1.0,
#  'dense_units': 165.0,
#  'dropout': 0.0,
#  'filter_units': 112.0,
#  'learning_rate': 0.00022058511937932088,
#  'loss': 0.6102103590965271}
#              Status  Iteration  batch_size  conv_blocks  dense_layers  \
# Trial-ID
# 118       COMPLETED         14        32.0          2.0           1.0
# 132       COMPLETED         14        32.0          2.0           1.0
# 125       COMPLETED         14        32.0          2.0           1.0
# 124       COMPLETED         14        32.0          2.0           1.0
# 55        COMPLETED         14        32.0          1.0           1.0
# ...             ...        ...         ...          ...           ...
# 42        COMPLETED         14       128.0          1.0           1.0
# 2         COMPLETED         14        32.0          4.0           3.0
# 14        COMPLETED         14       128.0          2.0           2.0
# 90        COMPLETED         14       128.0          2.0           2.0
# 6         COMPLETED         14       128.0          2.0           1.0
#
#           dense_units   dropout  filter_units  learning_rate  Objective  \
# Trial-ID
# 118             165.0  0.000000         112.0       0.000221   0.818643
# 132             165.0  0.000000         111.0       0.000207   0.817002
# 125             165.0  0.000000         111.0       0.000298   0.815712
# 124             165.0  0.000000         112.0       0.000252   0.814911
# 55              165.0  0.217877         112.0       0.000238   0.814808
# ...               ...       ...           ...            ...        ...
# 42               46.0  0.000000          61.0       0.000012   0.764251
# 2               133.0  0.265638          48.0       0.000012   0.762354
# 14              118.0  0.500000         101.0       0.000010   0.743867
# 90              159.0  0.500000          97.0       0.000010   0.743665
# 6               125.0  0.339376          40.0       0.000012   0.742966
#
#           accuracy       auc      loss
# Trial-ID
# 118       0.739347  0.818643  0.610210
# 132       0.737093  0.817002  0.602808
# 125       0.735533  0.815712  0.586414
# 124       0.740533  0.814911  0.780500
# 55        0.738360  0.814808  0.601014
# ...            ...       ...       ...
# 42        0.695213  0.764251  0.578302
# 2         0.689600  0.762354  0.589154
# 14        0.677293  0.743867  0.597405
# 90        0.679053  0.743665  0.597437
# 6         0.678893  0.742966  0.597871
#
# [136 rows x 13 columns]
# HL 0p3
# {'Iteration': 14,
#  'Objective': 0.8510500192642212,
#  'Status': 'COMPLETED',
#  'accuracy': 0.7698266506195068,
#  'auc': 0.8510500192642212,
#  'batch_size': 128.0,
#  'dense_layers': 7.0,
#  'dense_units': 189.0,
#  'dropout': 0.0,
#  'learning_rate': 0.001,
#  'loss': 0.5009739995002747}
#              Status  Iteration  batch_size  dense_layers  dense_units  \
# Trial-ID
# 93        COMPLETED         14       128.0           7.0        189.0
# 120       COMPLETED         14        32.0           4.0        157.0
# 116       COMPLETED         14        32.0           4.0        157.0
# 63        COMPLETED         14        64.0           5.0        100.0
# 55        COMPLETED         14        64.0           4.0        125.0
# ...             ...        ...         ...           ...          ...
# 56        COMPLETED         14        64.0           6.0        179.0
# 59        COMPLETED         14       128.0           6.0        200.0
# 4         COMPLETED         14       128.0           4.0         25.0
# 29        COMPLETED         14        32.0           8.0        133.0
# 51        COMPLETED         14       128.0           6.0         36.0
#
#            dropout  learning_rate  Objective  accuracy       auc      loss
# Trial-ID
# 93        0.000000       0.001000   0.851050  0.769827  0.851050  0.500974
# 120       0.000000       0.001000   0.849719  0.767147  0.849719  0.489375
# 116       0.000000       0.001000   0.849350  0.765907  0.849350  0.495887
# 63        0.000000       0.001000   0.849306  0.765720  0.849306  0.488751
# 55        0.000000       0.001000   0.849262  0.768147  0.849262  0.491251
# ...            ...            ...        ...       ...       ...       ...
# 56        0.500000       0.000010   0.708531  0.650107  0.708531  0.674307
# 59        0.500000       0.000010   0.697260  0.638253  0.697260  0.680126
# 4         0.473915       0.000017   0.598329  0.558187  0.598329  0.688404
# 29        0.500000       0.000010   0.531601  0.507920  0.531601  0.692948
# 51        0.500000       0.000010   0.487667  0.488000  0.487667  0.693514
#
# [150 rows x 11 columns]
