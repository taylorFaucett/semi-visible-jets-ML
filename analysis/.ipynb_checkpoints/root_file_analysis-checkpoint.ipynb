# %%
import uproot
import numpy as np
import tqdm
import glob
import os
from natsort import natsorted
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import trange, tqdm
# from pyjet import cluster
# from pyjet.testdata import get_event
from numpy.lib.recfunctions import append_fields
import calc
svj_path = "/home/tfaucett/Projects/svj-production"

# %% [markdown]
# ## Mjj plot

# %%
root_files = glob.glob(f"{svj_path}/data/root_files/*.root")
for root_file in root_files:
    events = uproot.open(root_file)["Delphes"]
    branches = ["Jet.PT", "Jet.Eta", "Jet.Phi", "Jet.Mass"]
    jets = events.arrays(branches=branches, outputtype=pd.DataFrame, flatten=True)
    jets.columns = jets.columns.str.lower().str.replace("jet.", "")
    file_name = os.path.basename(root_file).split(".root")[0]
    minv_file = f"data/minv/{file_name}.feather"
    minvs = []
    for idx, entry in tqdm(jets.groupby("entry")):
        if len(entry) >= 2:
            j1 = entry.iloc[0]
            j2 = entry.iloc[1]
            abs_eta = np.absolute(j1.eta - j2.eta)
            if j1.pt > 440 and j2.pt > 60:# and abs_eta <= 1.2:
                minv = calc.mass_inv(j1, j2)
                minvs.append(minv)
    df = pd.DataFrame({"minv":minvs})
    df.to_feather(minv_file)
# Out:
# 100%|██████████| 9367/9367 [00:01<00:00, 8910.15it/s]
# 100%|██████████| 11857/11857 [00:01<00:00, 6162.87it/s]
# 100%|██████████| 14575/14575 [00:03<00:00, 4285.39it/s]
# 100%|██████████| 13266/13266 [00:03<00:00, 4370.33it/s]
# 100%|██████████| 14586/14586 [00:03<00:00, 4514.51it/s]
# 100%|██████████| 14427/14427 [00:03<00:00, 4804.02it/s]

# %%
from matplotlib import rcParams
rcParams['font.family'] = 'serif'
plt.rcParams.update({'font.size': 12})
plt.figure(figsize=(8, 6))
lb, ub, n_bins = 7e2, 1e4, 100

minv_files = natsorted(glob.glob("data/minv/*"))

density = False
for file in minv_files:
    X = pd.read_feather(file).minv
    deets = os.path.basename(file).split("_")
    rinv = deets[-3].replace("p", ".")
    lam = deets[-1].replace("p", ".").split(".feather")[0]
    label = "$M_{Z'}=1.5\, TeV, r_{inv}=%s, \Lambda=%s$" %(rinv, lam)
    bins = np.linspace(lb, ub, n_bins)
    if lam == "10.0":
        plt.hist(X, bins=bins, histtype="step", density=density, label=label, linewidth=3)
plt.yscale("log")
plt.xscale("log")
plt.xlim([lb, ub])
if density:
    plt.ylim([1e-6, 1e0])
else:
    plt.ylim([1e0, 5e6])
    plt.text(2.6e3, 4e-1, "$3\\times10^3$")
plt.xlabel("$M_{jj} [GeV]$")
plt.ylabel("Events")
plt.legend()
plt.savefig("figures/Mjj.png")
plt.show()

# %% [markdown]
# ## MET Plt

# %%
root_files = glob.glob(f"{svj_path}/data/root_files/*.root")
bins = np.linspace(0, 2000, 25)
for root_file in tqdm(root_files):
    events = uproot.open(root_file)["Delphes"]
    branches = ["MissingET.MET"]
    MET = events.arrays(branches=branches, outputtype=pd.DataFrame, flatten=True)
    deets = os.path.basename(root_file).split("_")
    print(deets)
    rinv = deets[-3].replace("p", ".")
    lam = deets[-1].replace("p", ".").split(".feather")[0]
    label = "$M_{Z'}=1.5\, TeV, r_{inv}=%s, \Lambda=%s$" %(rinv, lam)
    plt.hist(MET.values, bins=bins, histtype="step", density=True, label=f"rinv = {label}", linewidth=3)
plt.xlim([0, 2000])
plt.yscale("log")
plt.xlabel("MET [GeV]")
plt.ylim([1e-7, 1e-2])
plt.legend()
plt.savefig("figures/MET.png")
plt.show()
# Out:
#  33%|███▎      | 2/6 [00:00<00:00,  8.86it/s]
# ['delphes', 'n', '20000', 'mZ', '1500p0', 'mXd', '5p0', 'rinv', '0p5', 'lam', '5p0.root']
# ['delphes', 'n', '20000', 'mZ', '1500p0', 'mXd', '5p0', 'rinv', '0p3', 'lam', '5p0.root']
#  67%|██████▋   | 4/6 [00:00<00:00,  9.07it/s]
# ['delphes', 'n', '20000', 'mZ', '1500p0', 'mXd', '10p0', 'rinv', '0p0', 'lam', '10p0.root']
# ['delphes', 'n', '20000', 'mZ', '1500p0', 'mXd', '5p0', 'rinv', '0p0', 'lam', '5p0.root']
# 100%|██████████| 6/6 [00:00<00:00,  9.28it/s]
# ['delphes', 'n', '20000', 'mZ', '1500p0', 'mXd', '10p0', 'rinv', '0p3', 'lam', '10p0.root']
# ['delphes', 'n', '20000', 'mZ', '1500p0', 'mXd', '10p0', 'rinv', '0p5', 'lam', '10p0.root']

# %%
root_file = "/home/tfaucett/Projects/semi-visible-jets/data/root_files/delphes_n_20000_mZ_1500_mXd_10_rinv_0p0_lam_5p0.root"
events = uproot.open(root_file)["Delphes"]["MissingET"]
events.keys()
# Out:
# [b'Event',
#  b'Event_size',
#  b'EventLHEF',
#  b'EventLHEF_size',
#  b'WeightLHEF',
#  b'WeightLHEF_size',
#  b'Particle',
#  b'Particle_size',
#  b'Track',
#  b'Track_size',
#  b'Tower',
#  b'Tower_size',
#  b'EFlowTrack',
#  b'EFlowTrack_size',
#  b'EFlowPhoton',
#  b'EFlowPhoton_size',
#  b'EFlowNeutralHadron',
#  b'EFlowNeutralHadron_size',
#  b'GenJet',
#  b'GenJet_size',
#  b'GenMissingET',
#  b'GenMissingET_size',
#  b'Jet',
#  b'Jet_size',
#  b'Electron',
#  b'Electron_size',
#  b'Photon',
#  b'Photon_size',
#  b'Muon',
#  b'Muon_size',
#  b'MissingET',
#  b'MissingET_size',
#  b'ScalarHT',
#  b'ScalarHT_size']
